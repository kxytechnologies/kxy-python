# %% [markdown]
# # CT Slices (UCI, Regression, n=53500, d=385)

# %% [markdown]
# ## Loading The Data

# %%
from kxy_datasets.uci_regressions import CTSlices # pip install kxy_datasets

# %%
dataset = CTSlices()
df = dataset.df # Retrieve the dataset as a pandas dataframe
y_column = dataset.y_column # The name of the column corresponding to the target
problem_type = dataset.problem_type # 'regression' or 'classification'

# %%
df.kxy.describe() # Visualize a summary of the data
# Out:
#
# -----------------
# Column: patientId
# -----------------
# Type:   Continuous
# Max:    96
# p75:    70
# Mean:   47
# Median: 46
# p25:    23
# Min:    0.0
#
# -----------------
# Column: reference
# -----------------
# Type:   Continuous
# Max:    97
# p75:    63
# Mean:   47
# Median: 43
# p25:    29
# Min:    1.7
#
# --------------
# Column: value0
# --------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# --------------
# Column: value1
# --------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value10
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value100
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value101
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value102
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value103
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.2
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value104
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.3
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value105
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.2
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value106
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value107
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value108
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value109
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.1
# Median: 0.0
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value11
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value110
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value111
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value112
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value113
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.5
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value114
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.7
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value115
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.6
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value116
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.3
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value117
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value118
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value119
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value12
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value120
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value121
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value122
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value123
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.5
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value124
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.7
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value125
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.8
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value126
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.7
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value127
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value128
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.1
# Median: 0.0
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value129
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value13
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.2
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value130
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value131
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value132
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value133
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.2
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value134
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.3
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value135
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.7
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value136
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.6
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value137
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value138
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value139
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.1
# Median: 0.0
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value14
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.3
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value140
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value141
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value142
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value143
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value144
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.1
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value145
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.7
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value146
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value147
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value148
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value149
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value15
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.2
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value150
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.3
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value151
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.2
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value152
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value153
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value154
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.2
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value155
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.3
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value156
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value157
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value158
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.1
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value159
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value16
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value160
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.4
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value161
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.6
# Mean:   0.3
# Median: 0.2
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value162
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.6
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value163
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.4
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value164
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value165
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value166
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value167
# ----------------
# Type:   Continuous
# Max:    0.9
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value168
# ----------------
# Type:   Continuous
# Max:    0.9
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value169
# ----------------
# Type:   Continuous
# Max:    0.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value17
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value170
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.5
# Mean:   0.2
# Median: 0.1
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value171
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.7
# Mean:   0.4
# Median: 0.3
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value172
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.8
# Mean:   0.4
# Median: 0.5
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value173
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.8
# Mean:   0.4
# Median: 0.3
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value174
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value175
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value176
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.1
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value177
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value178
# ----------------
# Type:   Continuous
# Max:    0.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value179
# ----------------
# Type:   Continuous
# Max:    -0.2
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value18
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value180
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.4
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value181
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.7
# Mean:   0.3
# Median: 0.3
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value182
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.8
# Mean:   0.4
# Median: 0.5
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value183
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.8
# Mean:   0.4
# Median: 0.3
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value184
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.2
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value185
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value186
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.1
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value187
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value188
# ----------------
# Type:   Continuous
# Max:    0.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value189
# ----------------
# Type:   Continuous
# Max:    -0.2
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value19
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.1
# Median: 0.0
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value190
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.4
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value191
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.6
# Mean:   0.3
# Median: 0.1
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value192
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.6
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value193
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.4
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value194
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value195
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value196
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value197
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value198
# ----------------
# Type:   Continuous
# Max:    0.8
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value199
# ----------------
# Type:   Continuous
# Max:    0.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# --------------
# Column: value2
# --------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value20
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value200
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.3
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value201
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.3
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value202
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value203
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value204
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.3
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value205
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.3
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value206
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value207
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value208
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.1
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value209
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value21
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value210
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.1
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value211
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value212
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value213
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value214
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.1
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value215
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.7
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value216
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value217
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value218
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value219
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value22
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value220
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value221
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value222
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.1
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value223
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.3
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value224
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.4
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value225
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.7
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value226
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.6
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value227
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value228
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value229
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.1
# Median: 0.0
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value23
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.1
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value230
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value231
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value232
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value233
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.4
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value234
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.7
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value235
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.8
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value236
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.7
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value237
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value238
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.1
# Median: 0.0
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value239
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value24
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.1
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value240
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value241
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value242
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value243
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value244
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value245
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value246
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value247
# ----------------
# Type:   Continuous
# Max:    0.7
# p75:    0.0
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value248
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value249
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value25
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value250
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value251
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.4
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value252
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value253
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value254
# ----------------
# Type:   Continuous
# Max:    0.9
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value255
# ----------------
# Type:   Continuous
# Max:    0.5
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value256
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value257
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value258
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value259
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.4
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value26
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value260
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.9
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value261
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value262
# ----------------
# Type:   Continuous
# Max:    0.6
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value263
# ----------------
# Type:   Continuous
# Max:    0.8
# p75:    0.0
# Mean:   -0.1
# Median: 0.0
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value264
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value265
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value266
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value267
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value268
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value269
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.1
# Median: 0.0
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value27
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value270
# ----------------
# Type:   Continuous
# Max:    0.9
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value271
# ----------------
# Type:   Continuous
# Max:    0.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value272
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value273
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value274
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value275
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value276
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value277
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.1
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value278
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value279
# ----------------
# Type:   Continuous
# Max:    0.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value28
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value280
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value281
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value282
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value283
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.4
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value284
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value285
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value286
# ----------------
# Type:   Continuous
# Max:    0.8
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value287
# ----------------
# Type:   Continuous
# Max:    0.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value288
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value289
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value29
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value290
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.4
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value291
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.4
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value292
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value293
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value294
# ----------------
# Type:   Continuous
# Max:    0.8
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value295
# ----------------
# Type:   Continuous
# Max:    0.8
# p75:    0.0
# Mean:   -0.1
# Median: 0.0
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value296
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value297
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value298
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value299
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# --------------
# Column: value3
# --------------
# Type:   Continuous
# Max:    1.0
# p75:    0.4
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value30
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value300
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.9
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value301
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value302
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value303
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value304
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value305
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value306
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value307
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value308
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.9
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value309
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value31
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value310
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value311
# ----------------
# Type:   Continuous
# Max:    0.7
# p75:    0.0
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value312
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value313
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.4
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value314
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value315
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value316
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.9
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value317
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value318
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value319
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value32
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value320
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value321
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.4
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value322
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.4
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value323
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value324
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value325
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value326
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value327
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value328
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value329
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value33
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.1
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value330
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value331
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value332
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value333
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value334
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value335
# ----------------
# Type:   Continuous
# Max:    0.5
# p75:    0.0
# Mean:   -0.1
# Median: 0.0
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value336
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value337
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value338
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value339
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value34
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value340
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value341
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.1
# Median: 0.0
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value342
# ----------------
# Type:   Continuous
# Max:    0.8
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value343
# ----------------
# Type:   Continuous
# Max:    0.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value344
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value345
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value346
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value347
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value348
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value349
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value35
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value350
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value351
# ----------------
# Type:   Continuous
# Max:    -0.2
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value352
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value353
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value354
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value355
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value356
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value357
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.1
# Median: 0.0
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value358
# ----------------
# Type:   Continuous
# Max:    0.9
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value359
# ----------------
# Type:   Continuous
# Max:    0.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value36
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value360
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value361
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value362
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value363
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value364
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value365
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value366
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value367
# ----------------
# Type:   Continuous
# Max:    0.0
# p75:    0.0
# Mean:   -0.1
# Median: 0.0
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value368
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value369
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value37
# ---------------
# Type:   Continuous
# Max:    0.8
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value370
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.4
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value371
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value372
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value373
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value374
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value375
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value376
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value377
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value378
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.4
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value379
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    1.0
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value38
# ---------------
# Type:   Continuous
# Max:    0.0
# p75:    0.0
# Mean:   -0.1
# Median: 0.0
# p25:    -0.2
# Min:    -0.2
#
# ----------------
# Column: value380
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.9
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ----------------
# Column: value381
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value382
# ----------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ----------------
# Column: value383
# ----------------
# Type:   Continuous
# Max:    0.9
# p75:    0.0
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value39
# ---------------
# Type:   Continuous
# Max:    0.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# --------------
# Column: value4
# --------------
# Type:   Continuous
# Max:    1.0
# p75:    0.7
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value40
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value41
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value42
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.1
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value43
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value44
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value45
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value46
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value47
# ---------------
# Type:   Continuous
# Max:    0.9
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value48
# ---------------
# Type:   Continuous
# Max:    0.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value49
# ---------------
# Type:   Continuous
# Max:    0.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# --------------
# Column: value5
# --------------
# Type:   Continuous
# Max:    1.0
# p75:    0.7
# Mean:   0.3
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value50
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value51
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value52
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.1
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value53
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.2
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value54
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.1
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value55
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value56
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.1
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value57
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value58
# ---------------
# Type:   Continuous
# Max:    0.7
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value59
# ---------------
# Type:   Continuous
# Max:    -0.2
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# --------------
# Column: value6
# --------------
# Type:   Continuous
# Max:    1.0
# p75:    0.4
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value60
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value61
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value62
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.1
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value63
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.2
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value64
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value65
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value66
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.1
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value67
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value68
# ---------------
# Type:   Continuous
# Max:    0.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value69
# ---------------
# Type:   Continuous
# Max:    -0.2
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# --------------
# Column: value7
# --------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value70
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value71
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value72
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.1
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value73
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value74
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value75
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value76
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value77
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value78
# ---------------
# Type:   Continuous
# Max:    0.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value79
# ---------------
# Type:   Continuous
# Max:    0.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# --------------
# Column: value8
# --------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value80
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value81
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value82
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value83
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value84
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value85
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value86
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value87
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value88
# ---------------
# Type:   Continuous
# Max:    0.0
# p75:    0.0
# Mean:   -0.1
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value89
# ---------------
# Type:   Continuous
# Max:    0.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# --------------
# Column: value9
# --------------
# Type:   Continuous
# Max:    1.0
# p75:    -0.2
# Mean:   -0.2
# Median: -0.2
# p25:    -0.2
# Min:    -0.2
#
# ---------------
# Column: value90
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value91
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value92
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value93
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value94
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.2
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value95
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.1
# Median: 0.0
# p25:    0.0
# Min:    0.0
#
# ---------------
# Column: value96
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value97
# ---------------
# Type:   Continuous
# Max:    1.0
# p75:    0.0
# Mean:   0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value98
# ---------------
# Type:   Continuous
# Max:    0.8
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2
#
# ---------------
# Column: value99
# ---------------
# Type:   Continuous
# Max:    0.2
# p75:    0.0
# Mean:   -0.0
# Median: 0.0
# p25:    0.0
# Min:    -0.2

# %% [markdown]
# ## Data Valuation

# %%
df.kxy.data_valuation(y_column, problem_type=problem_type)
# Out:
# [====================================================================================================] 100% ETA: 0s    Duration: 0s
#   Achievable R-Squared Achievable Log-Likelihood Per Sample Achievable RMSE
# 0                 1.00                            -3.23e-01        3.61e-01

# %% [markdown]
# ## Automatic (Model-Free) Variable Selection

# %%
df.kxy.variable_selection(y_column, problem_type=problem_type)
# Out:
# [====================================================================================================] 100% ETA: 0s    Duration: 0s
#                     Variable Running Achievable R-Squared  \
# Selection Order
# 0                No Variable                         0.00
# 1                   value127                         0.61
# 2                   value135                         0.76
# 3                   value114                         0.76
# 4                   value273                         0.87
# ...                      ...                          ...
# 376                 value220                         1.00
# 377                  value92                         1.00
# 378                  value14                         1.00
# 379                 value190                         1.00
# 380                 value287                         1.00
#
#                 Running Achievable RMSE
# Selection Order
# 0                              2.23e+01
# 1                              1.40e+01
# 2                              1.09e+01
# 3                              1.09e+01
# 4                                  8.06
# ...                                 ...
# 376                                0.36
# 377                                0.36
# 378                                0.36
# 379                                0.36
# 380                                0.36
#
# [381 rows x 3 columns]
