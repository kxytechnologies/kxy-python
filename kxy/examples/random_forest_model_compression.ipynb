# %% [markdown]
# # Random Forest: How To Reduce Your Production Model Size by 95%

# %% [markdown]
# In this tutorial we illustrate using 38 real-world regression and classification problems that, thanks to the `kxy` package, you can achieve the same Random Forest performance with only 5% of features.

# %% [markdown]
# ## Necessary Imports

# %%
import os
import json
import logging
logging.basicConfig(level=logging.WARNING)

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, r2_score, mean_squared_error, roc_auc_score

from kxy_datasets.regressions import all_regression_datasets
from kxy_datasets.classifications import all_classification_datasets

from kxy.learning import get_sklearn_learner
from kxy.misc.predictors import NaivePredictor
from kxy.learning.leanml_predictor import LeanMLPredictor

# %% [markdown]
# ## The Basic Function To Load/Train/Save A Compressed Version of Your Model

# %%
def train_model(train_features_df, target_column, problem_type, learner_func, \
                feature_selection_method, path):
    '''
    Train a custom model with or without feature compression.
    '''
    cls = LeanMLPredictor if feature_selection_method == 'leanml' else NaivePredictor
    try:
        # First try to load the model from disk
        predictor = cls.load(path, learner_func)
    except:
        try:
            # Train the model from scratch if it is not found from disk
            results = train_features_df.kxy.fit(target_column, learner_func, \
                problem_type=problem_type, feature_selection_method=feature_selection_method)
        except:
            # Some models do not like NAs
            train_features_df = train_features_df.dropna(axis=0)
            results = train_features_df.kxy.fit(target_column, learner_func, \
                problem_type=problem_type, feature_selection_method=feature_selection_method)
        predictor = results['predictor']
        
        # Save the trained model to disk
        predictor.save(path)
    
    return predictor

# %% [markdown]
# ## Some Utility Functions To Run Experiments

# %%
os.makedirs('./cache/', exist_ok=True)

# Utility functions
def regression_benchmark(learner_func, model_name):
    '''
    Run all regression experiments for a given model.
    '''
    try:
        with open('./cache/%s_regression_benchmark_perfs.json' % model_name, 'r') as f:
            perfs = json.load(f)
    except:
        perfs = {}

    try:
        with open('./cache/%s_regression_benchmark_n_features.json' % model_name, 'r') as f:
            n_features = json.load(f)
    except:
        n_features = {}
        
    try:
        with open('./cache/regression_n_rows.json', 'r') as f:
            n_rows = json.load(f)
    except:
        n_rows = {}

    for dataset_cls in all_regression_datasets:
        print()
        print('Dataset: %s' % dataset_cls.__name__)
        dataset = dataset_cls()
        target_column = dataset.y_column
        dataset_name = dataset.name
        perfs[dataset_name] = perfs.get(dataset_name, {})
        n_features[dataset_name] = n_features.get(dataset_name, {})
        df = dataset.df
        n_rows[dataset_name] = df.shape[0]

        # Features generation
        features_df = df.kxy.generate_features(entity=None, max_lag=None, entity_name='*', \
            exclude=[target_column])
        train_features_df, test_features_df = train_test_split(features_df, test_size=0.2, \
            random_state=0)
        test_labels_df = test_features_df.loc[:, [target_column]]
        test_features_df = test_features_df.drop(target_column, axis=1)
        path = './cache/%s-%s-regression-benchmark.sav' % (model_name, dataset_name)

        print('%s %d Features, Target: %s' % (dataset_name, train_features_df.shape[1]-1, target_column))
        
        # LeanML vs. No Feature Seletion
        dataset_performance = perfs[dataset_name].copy()
        dataset_n_features = n_features[dataset_name].copy()
        for feature_selection_method in ['leanml', 'none']:
            # Training
            predictor = train_model(train_features_df, target_column, 'regression', learner_func, \
                feature_selection_method, path)                    
            n_selected_features = len(predictor.selected_variables)

            # Evaluation
            try:
                try:
                    test_predictions_df = predictor.predict(test_features_df)
                except:
                    nan_features = test_features_df.isna().any(axis=1)
                    test_features_df = test_features_df.loc[np.logical_not(nan_features), :]
                    test_predictions_df = predictor.predict(test_features_df)
                    test_labels_df = test_labels_df.loc[np.logical_not(nan_features), :]

                perf = r2_score(\
                    test_labels_df[target_column].values, \
                    test_predictions_df[target_column].values)
            except:
                logging.exception('Somthing bad happened')
                perf = 0.0
                
            print('%s, Feature Selection Method: %s --- R-Squared: %.2f, Number of Selected Features: %d' % (\
                dataset_name, feature_selection_method, perf, n_selected_features))
            
            dataset_performance[feature_selection_method]=float(perf)
            dataset_n_features[feature_selection_method]=int(n_selected_features)
            
        perfs[dataset_name]=dataset_performance.copy()
        with open('./cache/%s_regression_benchmark_perfs.json' % model_name, 'w') as f:
            json.dump(perfs, f)

        n_features[dataset_name]=dataset_n_features.copy()
        with open('./cache/%s_regression_benchmark_n_features.json' % model_name, 'w') as f:
            json.dump(n_features, f)

        with open('./cache/regression_n_rows.json', 'w') as f:
            json.dump(n_rows, f)


def classification_benchmark(learner_func, model_name):
    '''
    Run all classification experiments for a given model.
    '''
    try:
        with open('./cache/%s_classification_benchmark_perfs.json' % model_name, 'r') as f:
            perfs = json.load(f)
    except:
        perfs = {}

    try:
        with open('./cache/%s_classification_benchmark_n_features.json' % model_name, 'r') as f:
            n_features = json.load(f)
    except:
        n_features = {}
        
    try:
        with open('./cache/classification_n_rows.json', 'r') as f:
            n_rows = json.load(f)
    except:
        n_rows = {}

    # LeanML
    for dataset_cls in all_classification_datasets:
        print()
        print('Dataset: %s' % dataset_cls.__name__)
        dataset = dataset_cls()
        target_column = dataset.y_column
        dataset_name = dataset.name
        perfs[dataset_name] = perfs.get(dataset_name, {})
        n_features[dataset_name] = n_features.get(dataset_name, {})
        df = dataset.df
        n_rows[dataset_name] = df.shape[0]

        # Features generation
        features_df = df.kxy.generate_features(entity=None, max_lag=None, entity_name='*', \
            exclude=[target_column])

        if target_column in features_df:
            target_df = pd.get_dummies(df[target_column], prefix=str(target_column))
            features_df = features_df.drop(target_column, axis=1)
            features_df = pd.concat([features_df, target_df], axis=1)

        train_features_df, test_features_df = train_test_split(features_df, test_size=0.2, \
            random_state=0)
        target_columns = [_ for _ in features_df.columns if str(_).startswith(str(target_column))]
        target_column = target_columns[0]
        test_labels_df = test_features_df.loc[:, [target_column]]
        train_labels_df = train_features_df.loc[:, [target_column]]

        for col in target_columns:
            if col != target_column:
                test_features_df = test_features_df.drop(col, axis=1)
                train_features_df = train_features_df.drop(col, axis=1)
            else:
                test_features_df = test_features_df.drop(col, axis=1)

        path = './cache/%s-%s-classification-benchmark.sav' % (model_name, dataset_name)
        print('%s %d Features, Target: %s' % (dataset_name, train_features_df.shape[1]-1, target_column))

        # LeanML vs. No Feature Seletion
        dataset_performance = perfs[dataset_name].copy()
        dataset_n_features = n_features[dataset_name].copy()
        for feature_selection_method in ['leanml', 'none']:
            # Training
            predictor = train_model(train_features_df, target_column, 'classification', learner_func, \
                feature_selection_method, path)                
            n_selected_features = len(predictor.selected_variables)

            # Evaluation
            try:
                try:
                    test_predictions_df = predictor.predict(test_features_df)
                except:
                    nan_features = test_features_df.isna().any(axis=1)
                    test_features_df = test_features_df.loc[np.logical_not(nan_features), :]
                    test_predictions_df = predictor.predict(test_features_df)
                    test_labels_df = test_labels_df.loc[np.logical_not(nan_features), :]
                perf = roc_auc_score(\
                    test_labels_df[target_column].values, \
                    test_predictions_df[target_column].values, \
                    multi_class='ovr')
            except:
                logging.exception('Somthing bad happened')
                perf = 0.5
                
            dataset_performance[feature_selection_method]=float(perf)
            dataset_n_features[feature_selection_method]=int(n_selected_features)

            print('%s, Feature Selection Method: %s --- AUC: %.2f, Number of Selected Features: %d' % (\
                dataset_name, feature_selection_method, perf, n_selected_features))
            
        perfs[dataset_name]=dataset_performance.copy()
        with open('./cache/%s_classification_benchmark_perfs.json' % model_name, 'w') as f:
            json.dump(perfs, f)

        n_features[dataset_name]=dataset_n_features.copy()
        with open('./cache/%s_classification_benchmark_n_features.json' % model_name, 'w') as f:
            json.dump(n_features, f)

        with open('./cache/classification_n_rows.json', 'w') as f:
            json.dump(n_rows, f)
            
            
        
def summarize_results():
    '''
    Print a dataframe summarizing all datasets used.
    '''
    print()
    model_name = 'rf'
    dataset_names = []
    sources = []
    ds = []
    leanml_ds = []
    ns = []
    problem_types = []
    full_ps = []
    comp_ps = []

    problem_type = None
    for l in [all_classification_datasets, all_regression_datasets]:
        problem_type = 'classification' if problem_type is None else 'regression'
        try:
            with open('./cache/%s_%s_benchmark_n_features.json' % (model_name, problem_type), 'r') as f:
                n_features = json.load(f)
            with open('./cache/%s_%s_benchmark_perfs.json' % (model_name, problem_type), 'r') as f:
                perfs = json.load(f)
            with open('./cache/%s_n_rows.json' % problem_type, 'r') as f:
                n_rows = json.load(f)

        except:
            logging.exception('Something bad happened')
            n_features = {}
            n_rows = {}

        sub_dataset_names = [_ for _ in n_rows.keys()]
        for dataset_name in sub_dataset_names:
            dataset_names += [dataset_name.replace('UCI', '').replace('Kaggle', '')]
            ns += [n_rows[dataset_name]]
            ds += [n_features[dataset_name]['none']] 
            leanml_ds += [n_features[dataset_name]['leanml']] 
            full_ps += [perfs[dataset_name]['none']] 
            comp_ps += [perfs[dataset_name]['leanml']] 
            sources += ['UCI' if 'UCI' in dataset_name else 'Kaggle']
            problem_types += [problem_type]

    df = pd.DataFrame(data={'Dataset': dataset_names, 'Number of Rows': ns, 'Number of Candidate Features': ds, \
                            'Number of Features Selected': leanml_ds, 'Performance (Full Model)': full_ps, \
                            'Performance (Compressed Model)': comp_ps, 'Problem Type': problem_types})
    df = df.sort_values(by=['Number of Candidate Features', 'Number of Rows', 'Problem Type'])
    df.reset_index(drop=True, inplace=True)
    
    print('Avg. Performance Full Model: %.2f' % np.mean(df['Performance (Full Model)']))
    print('Avg. Performance Compressed Model: %.2f' % np.mean(df['Performance (Compressed Model)']))
    print('Avg. Compression Rate: %d%s' % (int(np.round(100.*(1.-np.mean(1.*\
                            df['Number of Features Selected']/df['Number of Candidate Features'])))), '%'))
    print('Weighted Avg. Compression Rate: %d%s' % (int(np.round(100.*(1.-np.sum(1.*\
                            df['Number of Features Selected']/np.sum(df['Number of Candidate Features']))))), '%'))
    pd.set_option('display.float_format','{:.2f}'.format)
    
    return df

# %%
def rf_regression_benchmark():
    '''
    Run all regression experiments for Random Forest.
    '''
    regressor_cls = get_sklearn_learner('sklearn.ensemble.RandomForestRegressor', \
        min_samples_split=0.01, max_samples=0.5, n_estimators=100)
    regression_benchmark(regressor_cls, 'rf')


def rf_classification_benchmark():
    '''
    Run all classification experiments for Random Forest.
    '''
    classifier_cls = get_sklearn_learner('sklearn.ensemble.RandomForestClassifier', \
        min_samples_split=0.01, max_samples=0.5, n_estimators=100)
    classification_benchmark(classifier_cls, 'rf')
    
    
def run_experiments():
    '''
    Run all experiments.
    '''
    print()
    print('============================')
    print('    Model: Random Forest    ')
    print('============================')
    print()
    print('Regression Datasets')
    rf_regression_benchmark()

    print()
    print('Classification Datasets')
    rf_classification_benchmark()

# %% [markdown]
# ## Run All Experiments

# %%
run_experiments()
# Out:
# ============================
#     Model: Random Forest
# ============================
#
# Regression Datasets
#
# Dataset: Abalone
# UCIAbalone 38 Features, Target: Age
# UCIAbalone, Feature Selection Method: leanml --- R-Squared: 0.57, Number of Selected Features: 7
# UCIAbalone, Feature Selection Method: none --- R-Squared: 0.57, Number of Selected Features: 38
#
# Dataset: AirFoil
# UCIAirFoil 25 Features, Target: Sound Pressure
# UCIAirFoil, Feature Selection Method: leanml --- R-Squared: 0.83, Number of Selected Features: 11
# UCIAirFoil, Feature Selection Method: none --- R-Squared: 0.81, Number of Selected Features: 25
#
# Dataset: AirQuality
# UCIAirQuality 70 Features, Target: C6H6(GT)
# UCIAirQuality, Feature Selection Method: leanml --- R-Squared: 1.00, Number of Selected Features: 2
# UCIAirQuality, Feature Selection Method: none --- R-Squared: 0.99, Number of Selected Features: 70
#
# Dataset: BikeSharing
# UCIBikeSharing 90 Features, Target: cnt
# UCIBikeSharing, Feature Selection Method: leanml --- R-Squared: 0.99, Number of Selected Features: 6
# UCIBikeSharing, Feature Selection Method: none --- R-Squared: 0.99, Number of Selected Features: 90
#
# Dataset: BlogFeedback
# UCIBlogFeedback 1400 Features, Target: y
# UCIBlogFeedback, Feature Selection Method: leanml --- R-Squared: 0.55, Number of Selected Features: 13
# UCIBlogFeedback, Feature Selection Method: none --- R-Squared: 0.55, Number of Selected Features: 1400
#
# Dataset: CTSlices
# UCICTSlices 1925 Features, Target: reference
# UCICTSlices, Feature Selection Method: leanml --- R-Squared: 0.91, Number of Selected Features: 29
# UCICTSlices, Feature Selection Method: none --- R-Squared: 0.95, Number of Selected Features: 1925
#
# Dataset: Concrete
# UCIConcrete 40 Features, Target: Concrete Compressive Strength
# UCIConcrete, Feature Selection Method: leanml --- R-Squared: 0.89, Number of Selected Features: 12
# UCIConcrete, Feature Selection Method: none --- R-Squared: 0.89, Number of Selected Features: 40
#
# Dataset: EnergyEfficiency
# UCIEnergyEfficiency 45 Features, Target: Y1
# UCIEnergyEfficiency, Feature Selection Method: leanml --- R-Squared: 0.99, Number of Selected Features: 6
# UCIEnergyEfficiency, Feature Selection Method: none --- R-Squared: 0.99, Number of Selected Features: 45
#
# Dataset: FacebookComments
# UCIFacebookComments 265 Features, Target: y
# UCIFacebookComments, Feature Selection Method: leanml --- R-Squared: 0.36, Number of Selected Features: 9
# UCIFacebookComments, Feature Selection Method: none --- R-Squared: 0.36, Number of Selected Features: 265
#
# Dataset: NavalPropulsion
# UCINavalPropulsion 85 Features, Target: GT Compressor Decay
# UCINavalPropulsion, Feature Selection Method: leanml --- R-Squared: 0.92, Number of Selected Features: 4
# UCINavalPropulsion, Feature Selection Method: none --- R-Squared: 0.93, Number of Selected Features: 85
#
# Dataset: OnlineNews
# UCIOnlineNews 290 Features, Target:  shares
# UCIOnlineNews, Feature Selection Method: leanml --- R-Squared: 0.02, Number of Selected Features: 26
# UCIOnlineNews, Feature Selection Method: none --- R-Squared: 0.00, Number of Selected Features: 290
#
# Dataset: Parkinson
# UCIParkinson 105 Features, Target: motor_UPDRS
# UCIParkinson, Feature Selection Method: leanml --- R-Squared: 0.99, Number of Selected Features: 5
# UCIParkinson, Feature Selection Method: none --- R-Squared: 0.99, Number of Selected Features: 105
#
# Dataset: PowerPlant
# UCIPowerPlant 20 Features, Target: PE
# UCIPowerPlant, Feature Selection Method: leanml --- R-Squared: 0.95, Number of Selected Features: 10
# UCIPowerPlant, Feature Selection Method: none --- R-Squared: 0.95, Number of Selected Features: 20
#
# Dataset: RealEstate
# UCIRealEstate 30 Features, Target: Y house price of unit area
# UCIRealEstate, Feature Selection Method: leanml --- R-Squared: 0.77, Number of Selected Features: 9
# UCIRealEstate, Feature Selection Method: none --- R-Squared: 0.77, Number of Selected Features: 30
#
# Dataset: SocialMediaBuzz
# UCISocialMediaBuzz 385 Features, Target: annotation
# UCISocialMediaBuzz, Feature Selection Method: leanml --- R-Squared: 0.78, Number of Selected Features: 7
# UCISocialMediaBuzz, Feature Selection Method: none --- R-Squared: 0.77, Number of Selected Features: 385
#
# Dataset: Superconductivity
# UCISuperconductivity 405 Features, Target: critical_temp
# UCISuperconductivity, Feature Selection Method: leanml --- R-Squared: 0.85, Number of Selected Features: 21
# UCISuperconductivity, Feature Selection Method: none --- R-Squared: 0.87, Number of Selected Features: 405
#
# Dataset: WhiteWineQuality
# UCIWhiteWineQuality 55 Features, Target: quality
# UCIWhiteWineQuality, Feature Selection Method: leanml --- R-Squared: 0.35, Number of Selected Features: 28
# UCIWhiteWineQuality, Feature Selection Method: none --- R-Squared: 0.35, Number of Selected Features: 55
#
# Dataset: YachtHydrodynamics
# UCIYachtHydrodynamics 30 Features, Target: Residuary Resistance
# UCIYachtHydrodynamics, Feature Selection Method: leanml --- R-Squared: 0.99, Number of Selected Features: 1
# UCIYachtHydrodynamics, Feature Selection Method: none --- R-Squared: 1.00, Number of Selected Features: 30
#
# Dataset: YearPredictionMSD
# UCIYearPredictionMSD 450 Features, Target: y
# UCIYearPredictionMSD, Feature Selection Method: leanml --- R-Squared: 0.21, Number of Selected Features: 22
# UCIYearPredictionMSD, Feature Selection Method: none --- R-Squared: 0.21, Number of Selected Features: 450
#
# Dataset: HousePricesAdvanced
# KaggleHousePricesAdvanced 432 Features, Target: SalePrice
# KaggleHousePricesAdvanced, Feature Selection Method: leanml --- R-Squared: 0.83, Number of Selected Features: 12
# KaggleHousePricesAdvanced, Feature Selection Method: none --- R-Squared: 0.80, Number of Selected Features: 432
#
# Classification Datasets
#
# Dataset: APSFailure
# UCIAPSFailure 850 Features, Target: class_neg
# UCIAPSFailure, Feature Selection Method: leanml --- AUC: 0.94, Number of Selected Features: 5
# UCIAPSFailure, Feature Selection Method: none --- AUC: 0.92, Number of Selected Features: 850
#
# Dataset: Adult
# UCIAdult 202 Features, Target: Income_ <=50K
# UCIAdult, Feature Selection Method: leanml --- AUC: 0.76, Number of Selected Features: 4
# UCIAdult, Feature Selection Method: none --- AUC: 0.75, Number of Selected Features: 202
#
# Dataset: Avila
# UCIAvila 50 Features, Target: Class_A
# UCIAvila, Feature Selection Method: leanml --- AUC: 0.91, Number of Selected Features: 34
# UCIAvila, Feature Selection Method: none --- AUC: 0.90, Number of Selected Features: 50
#
# Dataset: BankMarketing
# UCIBankMarketing 103 Features, Target: y_no
# UCIBankMarketing, Feature Selection Method: leanml --- AUC: 0.73, Number of Selected Features: 14
# UCIBankMarketing, Feature Selection Method: none --- AUC: 0.74, Number of Selected Features: 103
#
# Dataset: BankNote
# UCIBankNote 20 Features, Target: Is Fake_0
# UCIBankNote, Feature Selection Method: leanml --- AUC: 0.98, Number of Selected Features: 3
# UCIBankNote, Feature Selection Method: none --- AUC: 0.99, Number of Selected Features: 20
#
# Dataset: CardDefault
# UCICardDefault 115 Features, Target: default payment next month_0
# UCICardDefault, Feature Selection Method: leanml --- AUC: 0.66, Number of Selected Features: 25
# UCICardDefault, Feature Selection Method: none --- AUC: 0.66, Number of Selected Features: 115
#
# Dataset: DiabeticRetinopathy
# UCIDiabeticRetinopathy 95 Features, Target: y_0
# UCIDiabeticRetinopathy, Feature Selection Method: leanml --- AUC: 0.70, Number of Selected Features: 34
# UCIDiabeticRetinopathy, Feature Selection Method: none --- AUC: 0.68, Number of Selected Features: 95
#
# Dataset: EEGEyeState
# UCIEEGEyeState 70 Features, Target: y_0
# UCIEEGEyeState, Feature Selection Method: leanml --- AUC: 0.82, Number of Selected Features: 17
# UCIEEGEyeState, Feature Selection Method: none --- AUC: 0.81, Number of Selected Features: 70
#
# Dataset: Landsat
# UCILandsat 180 Features, Target: 36_1
# UCILandsat, Feature Selection Method: leanml --- AUC: 0.97, Number of Selected Features: 4
# UCILandsat, Feature Selection Method: none --- AUC: 0.97, Number of Selected Features: 180
#
# Dataset: LetterRecognition
# UCILetterRecognition 80 Features, Target: 0_A
# UCILetterRecognition, Feature Selection Method: leanml --- AUC: 0.88, Number of Selected Features: 25
# UCILetterRecognition, Feature Selection Method: none --- AUC: 0.89, Number of Selected Features: 80
#
# Dataset: MagicGamma
# UCIMagicGamma 50 Features, Target: 10_g
# UCIMagicGamma, Feature Selection Method: leanml --- AUC: 0.83, Number of Selected Features: 10
# UCIMagicGamma, Feature Selection Method: none --- AUC: 0.83, Number of Selected Features: 50
#
# Dataset: SensorLessDrive
# UCISensorLessDrive 240 Features, Target: 48_1.0
# UCISensorLessDrive, Feature Selection Method: leanml --- AUC: 0.97, Number of Selected Features: 25
# UCISensorLessDrive, Feature Selection Method: none --- AUC: 0.98, Number of Selected Features: 240
#
# Dataset: Shuttle
# UCIShuttle 45 Features, Target: 9_1
# UCIShuttle, Feature Selection Method: leanml --- AUC: 1.00, Number of Selected Features: 6
# UCIShuttle, Feature Selection Method: none --- AUC: 1.00, Number of Selected Features: 45
#
# Dataset: SkinSegmentation
# UCISkinSegmentation 15 Features, Target: y_1
# UCISkinSegmentation, Feature Selection Method: leanml --- AUC: 0.99, Number of Selected Features: 4
# UCISkinSegmentation, Feature Selection Method: none --- AUC: 0.99, Number of Selected Features: 15
#
# Dataset: HeartAttack
# KaggleHeartAttack 65 Features, Target: output_0
# KaggleHeartAttack, Feature Selection Method: leanml --- AUC: 0.87, Number of Selected Features: 9
# KaggleHeartAttack, Feature Selection Method: none --- AUC: 0.88, Number of Selected Features: 65
#
# Dataset: HeartDisease
# KaggleHeartDisease 65 Features, Target: target_0
# KaggleHeartDisease, Feature Selection Method: leanml --- AUC: 0.82, Number of Selected Features: 8
# KaggleHeartDisease, Feature Selection Method: none --- AUC: 0.88, Number of Selected Features: 65
#
# Dataset: Titanic
# KaggleTitanic 1754 Features, Target: Survived_0
# KaggleTitanic, Feature Selection Method: leanml --- AUC: 0.84, Number of Selected Features: 19
# KaggleTitanic, Feature Selection Method: none --- AUC: 0.81, Number of Selected Features: 1754
#
# Dataset: WaterQuality
# KaggleWaterQuality 45 Features, Target: Potability_0
# KaggleWaterQuality, Feature Selection Method: leanml --- AUC: 0.57, Number of Selected Features: 30
# KaggleWaterQuality, Feature Selection Method: none --- AUC: 0.60, Number of Selected Features: 45

# %% [markdown]
# ## Visualize All Results

# %%
results_df = summarize_results()
results_df
# Out:
# Avg. Performance Full Model: 0.79
# Avg. Performance Compressed Model: 0.79
# Avg. Compression Rate: 82%
# Weighted Avg. Compression Rate: 95%
#                 Dataset  Number of Rows  Number of Candidate Features  \
# 0      SkinSegmentation          245057                            15
# 1              BankNote            1372                            20
# 2            PowerPlant            9568                            20
# 3               AirFoil            1503                            25
# 4    YachtHydrodynamics             308                            30
# 5            RealEstate             414                            30
# 6               Abalone            4177                            38
# 7              Concrete            1030                            40
# 8      EnergyEfficiency             768                            45
# 9          WaterQuality            3276                            45
# 10              Shuttle           58000                            45
# 11           MagicGamma           19020                            50
# 12                Avila           20867                            50
# 13     WhiteWineQuality            4898                            55
# 14          HeartAttack             303                            65
# 15         HeartDisease             303                            65
# 16           AirQuality            8991                            70
# 17          EEGEyeState           14980                            70
# 18    LetterRecognition           20000                            80
# 19      NavalPropulsion           11934                            85
# 20          BikeSharing           17379                            90
# 21  DiabeticRetinopathy            1151                            95
# 22        BankMarketing           41188                           103
# 23            Parkinson            5875                           105
# 24          CardDefault           30000                           115
# 25              Landsat            6435                           180
# 26                Adult           48843                           202
# 27      SensorLessDrive           58509                           240
# 28     FacebookComments          209074                           265
# 29           OnlineNews           39644                           290
# 30      SocialMediaBuzz          583250                           385
# 31    Superconductivity           21263                           405
# 32  HousePricesAdvanced            1460                           432
# 33    YearPredictionMSD          515345                           450
# 34           APSFailure           76000                           850
# 35         BlogFeedback           60021                          1400
# 36              Titanic             891                          1754
# 37             CTSlices           53500                          1925
#
#     Number of Features Selected  Performance (Full Model)  \
# 0                             4                      0.99
# 1                             3                      0.99
# 2                            10                      0.95
# 3                            11                      0.81
# 4                             1                      1.00
# 5                             9                      0.77
# 6                             7                      0.57
# 7                            12                      0.89
# 8                             6                      0.99
# 9                            30                      0.60
# 10                            6                      1.00
# 11                           10                      0.83
# 12                           34                      0.90
# 13                           28                      0.35
# 14                            9                      0.88
# 15                            8                      0.88
# 16                            2                      0.99
# 17                           17                      0.81
# 18                           25                      0.89
# 19                            4                      0.93
# 20                            6                      0.99
# 21                           34                      0.68
# 22                           14                      0.74
# 23                            5                      0.99
# 24                           25                      0.66
# 25                            4                      0.97
# 26                            4                      0.75
# 27                           25                      0.98
# 28                            9                      0.36
# 29                           26                      0.00
# 30                            7                      0.77
# 31                           21                      0.87
# 32                           12                      0.80
# 33                           22                      0.21
# 34                            5                      0.92
# 35                           13                      0.55
# 36                           19                      0.81
# 37                           29                      0.95
#
#     Performance (Compressed Model)    Problem Type
# 0                             0.99  classification
# 1                             0.98  classification
# 2                             0.95      regression
# 3                             0.83      regression
# 4                             0.99      regression
# 5                             0.77      regression
# 6                             0.57      regression
# 7                             0.89      regression
# 8                             0.99      regression
# 9                             0.57  classification
# 10                            1.00  classification
# 11                            0.83  classification
# 12                            0.91  classification
# 13                            0.35      regression
# 14                            0.87  classification
# 15                            0.82  classification
# 16                            1.00      regression
# 17                            0.82  classification
# 18                            0.88  classification
# 19                            0.92      regression
# 20                            0.99      regression
# 21                            0.70  classification
# 22                            0.73  classification
# 23                            0.99      regression
# 24                            0.66  classification
# 25                            0.97  classification
# 26                            0.76  classification
# 27                            0.97  classification
# 28                            0.36      regression
# 29                            0.02      regression
# 30                            0.78      regression
# 31                            0.85      regression
# 32                            0.83      regression
# 33                            0.21      regression
# 34                            0.94  classification
# 35                            0.55      regression
# 36                            0.84  classification
# 37                            0.91      regression

# %%
print('Number of Selected Features: %d, Number of Candidate Features: %d' % 
      (results_df['Number of Features Selected'].sum(), results_df['Number of Candidate Features'].sum()))
# Out:
# Number of Selected Features: 516, Number of Candidate Features: 10229
